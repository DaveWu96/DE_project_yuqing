# %% [markdown]
# Note:
#
#     this notebook should be run in Vertex AI WorkBench

# %%
# The following two lines are only necessary to run once.
# Comment out otherwise for speed-up.
from google.cloud.bigquery import Client, QueryJobConfig
client = Client()

query = """SELECT * FROM `teaching-project-380417.yelp002.yelp_ml_prep_001` """
job = client.query(query)
df = job.to_dataframe()

# %%
df
# Out:
#      user_useful  user_review_count  user_funny  user_fans state  bus_stars  \
# 0              4                 12           0          0    TX        2.0
# 1            170                144          40          4    SD        4.5
# 2            687                 77         578         10    MT        5.0
# 3              0                  1           0          0    AB        2.5
# 4            122                152          43         11    AB        4.5
# ..           ...                ...         ...        ...   ...        ...
# 995            0                  1           0          0    AB        3.5
# 996          169                156          71         10    AB        4.5
# 997          499                186         259         12    AB        3.0
# 998         5067               1578        1469        159    AB        3.5
# 999         5067               1578        1469        159    AB        4.5
#
#      review_count     WiFi                                        review_text  \
# 0               9     None  Get on the mailing list! They send monthly dis...
# 1              42  u'free'                                        Ask for Rob
# 2               6    u'no'  Ask any staff member about what they do and ho...
# 3              70  u'free'  If coming on a Saturday, be prepared to wait, ...
# 4               6     None  Check the mindbody app or groupon for promotio...
# ..            ...      ...                                                ...
# 995            60    u'no'                    $$$$! but somtimes its worth it
# 996             6  u'free'  Make sure you arrive a bit early for your appo...
# 997            10  u'free'          Enjoy the free Wi-Fi that actually works!
# 998            52   'free'                                         100% vegan
# 999            10     None                               SweetLegs sold here!
#
#      stars
# 0      5.0
# 1      5.0
# 2      5.0
# 3      1.0
# 4      4.0
# ..     ...
# 995    5.0
# 996    5.0
# 997    4.0
# 998    2.0
# 999    5.0
#
# [1000 rows x 10 columns]

# %%
documents = df['review_text'].values
print(documents.shape, documents.dtype)
# Out:
# (406315,) object

# %%
documents
# Out:
# array(['Different menu and later hours from other location',
#        "Watch for low hanging duct work if you're on the tall side",
#        "Entrance has changed to Calgary Trail and not accessible from Gateway Blvd. Lots of construction still happening around there making it super hard to hear order being repeated and I'm guessing the same for those taking orders.",
#        ..., 'Great new tap growler selection',
#        'They offer a military discount',
#        'They now close at 8!! Still super fantastic!'], dtype=object)

# %%
# perfect (5 stars) and imperfect (1-4 stars) rating

# %%
df['target'] = df['stars'] == 5
target = df['target'].values
target[:5]
# Out:
# array([False, False, False,  True, False])

# %%
df.target.mean()
# Out:
# 0.5160306658626928

# %%
# create training dataset and test dataset
from sklearn.model_selection import train_test_split
documents_train, documents_test, target_train, target_test = train_test_split(
    documents, target, test_size = 0.7, random_state = 42)

# %%
# !pip install nltk
# Out:
# Collecting nltk
#   Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 12.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.7/site-packages (from nltk) (4.64.1)
# Requirement already satisfied: click in /opt/conda/lib/python3.7/site-packages (from nltk) (8.1.3)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.7/site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.7/site-packages (from nltk) (2022.10.31)
# Requirement already satisfied: importlib-metadata in /opt/conda/lib/python3.7/site-packages (from click->nltk) (6.0.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata->click->nltk) (3.15.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata->click->nltk) (4.5.0)
# Installing collected packages: nltk
# Successfully installed nltk-3.8.1

# %%
# NLP representation of the documents
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/jupyter/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# Create TfidfVectorizer, and name it vectorizer
tfidf_vectorizer = TfidfVectorizer(stop_words = stopwords.words('english'), max_features=2000)

# Train the model with training data
vectors_train = tfidf_vectorizer.fit_transform(documents_train).toarray()

# Get the vocab of tfidf
wordspitts = tfidf_vectorizer.get_feature_names()

# Use the trained model to transform test data
vectors_test = tfidf_vectorizer.transform(documents_test).toarray()
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
wordspitts
# Out:
# ['00',
#  '10',
#  '100',
#  '10am',
#  '10pm',
#  '11',
#  '11am',
#  '12',
#  '13',
#  '14',
#  '15',
#  '16',
#  '17',
#  '18',
#  '19',
#  '1st',
#  '20',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '2020',
#  '2021',
#  '21',
#  '22',
#  '24',
#  '25',
#  '27',
#  '2nd',
#  '2pm',
#  '30',
#  '30pm',
#  '35',
#  '3pm',
#  '3rd',
#  '40',
#  '45',
#  '4pm',
#  '4th',
#  '50',
#  '5pm',
#  '60',
#  '6pm',
#  '75',
#  '7pm',
#  '8pm',
#  '90',
#  '95',
#  '99',
#  '9pm',
#  'able',
#  'absolute',
#  'absolutely',
#  'ac',
#  'accept',
#  'access',
#  'accommodating',
#  'across',
#  'actual',
#  'actually',
#  'add',
#  'added',
#  'addition',
#  'additional',
#  'address',
#  'adult',
#  'advance',
#  'advantage',
#  'affordable',
#  'afraid',
#  'afternoon',
#  'ago',
#  'ahead',
#  'air',
#  'airport',
#  'al',
#  'alcohol',
#  'ale',
#  'allow',
#  'allowed',
#  'almond',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'alternative',
#  'although',
#  'always',
#  'amazing',
#  'amazingly',
#  'ambiance',
#  'ambience',
#  'american',
#  'amount',
#  'anniversary',
#  'another',
#  'answer',
#  'anymore',
#  'anyone',
#  'anything',
#  'anytime',
#  'anywhere',
#  'app',
#  'apparently',
#  'appetizer',
#  'appetizers',
#  'apple',
#  'appointment',
#  'appointments',
#  'appreciate',
#  'apps',
#  'april',
#  'area',
#  'around',
#  'arrive',
#  'arrived',
#  'art',
#  'artichoke',
#  'asada',
#  'asian',
#  'ask',
#  'asked',
#  'asking',
#  'ass',
#  'ate',
#  'atm',
#  'atmosphere',
#  'attention',
#  'attentive',
#  'attitude',
#  'august',
#  'authentic',
#  'available',
#  'ave',
#  'average',
#  'avocado',
#  'avoid',
#  'aware',
#  'away',
#  'awesome',
#  'awful',
#  'baby',
#  'back',
#  'bacon',
#  'bad',
#  'bag',
#  'bagel',
#  'bagels',
#  'bags',
#  'baked',
#  'bakery',
#  'ball',
#  'balls',
#  'banana',
#  'bananas',
#  'band',
#  'bands',
#  'bang',
#  'banh',
#  'bank',
#  'bar',
#  'barbara',
#  'barely',
#  'baristas',
#  'bars',
#  'bartender',
#  'bartenders',
#  'based',
#  'basic',
#  'basil',
#  'bathroom',
#  'bathrooms',
#  'bay',
#  'bbq',
#  'beach',
#  'bean',
#  'beans',
#  'beat',
#  'beautiful',
#  'become',
#  'bed',
#  'beef',
#  'beer',
#  'beers',
#  'behind',
#  'beignets',
#  'believe',
#  'bell',
#  'belly',
#  'benedict',
#  'berry',
#  'best',
#  'better',
#  'beverage',
#  'beware',
#  'beyond',
#  'big',
#  'bigger',
#  'bike',
#  'bill',
#  'bird',
#  'birthday',
#  'biscuit',
#  'biscuits',
#  'bisque',
#  'bit',
#  'bite',
#  'bites',
#  'black',
#  'blackened',
#  'bland',
#  'blend',
#  'block',
#  'bloody',
#  'blt',
#  'blue',
#  'blueberry',
#  'board',
#  'boba',
#  'body',
#  'boise',
#  'bomb',
#  'bone',
#  'bonus',
#  'book',
#  'books',
#  'booth',
#  'bother',
#  'bottle',
#  'bottles',
#  'bottomless',
#  'bought',
#  'bourbon',
#  'bowl',
#  'bowls',
#  'box',
#  'boy',
#  'boys',
#  'brand',
#  'brazilian',
#  'bread',
#  'break',
#  'breakfast',
#  'brew',
#  'brewery',
#  'brews',
#  'bri',
#  'bright',
#  'bring',
#  'brisket',
#  'broccoli',
#  'broken',
#  'broth',
#  'brought',
#  'brown',
#  'brunch',
#  'bubble',
#  'buck',
#  'bucks',
#  'buffalo',
#  'buffet',
#  'build',
#  'building',
#  'bun',
#  'buns',
#  'burger',
#  'burgers',
#  'burnt',
#  'burrito',
#  'burritos',
#  'business',
#  'busy',
#  'butter',
#  'buy',
#  'buying',
#  'byob',
#  'cabbage',
#  'caesar',
#  'cafe',
#  'cajun',
#  'cake',
#  'cakes',
#  'calamari',
#  'california',
#  'call',
#  'called',
#  'calling',
#  'calories',
#  'came',
#  'candy',
#  'cannot',
#  'cant',
#  'car',
#  'caramel',
#  'card',
#  'cards',
#  'care',
#  'careful',
#  'carne',
#  'carnitas',
#  'carry',
#  'cars',
#  'case',
#  'cash',
#  'cashier',
#  'casino',
#  'casual',
#  'cat',
#  'catch',
#  'catfish',
#  'cauliflower',
#  'cause',
#  'cent',
#  'center',
#  'cents',
#  'certain',
#  'ceviche',
#  'chai',
#  'chain',
#  'chairs',
#  'chance',
#  'change',
#  'changed',
#  'changes',
#  'changing',
#  'charge',
#  'charged',
#  'chargrilled',
#  'charro',
#  'cheap',
#  'cheaper',
#  'check',
#  'checked',
#  'checking',
#  'checkout',
#  'cheddar',
#  'cheese',
#  'cheeseburger',
#  'cheesecake',
#  'cheesesteak',
#  'cheesesteaks',
#  'chef',
#  'chefs',
#  'cherry',
#  'chicago',
#  'chicken',
#  'children',
#  'chili',
#  'chill',
#  'chinese',
#  'chip',
#  'chipotle',
#  'chips',
#  'chocolate',
#  'choice',
#  'choices',
#  'choose',
#  'chorizo',
#  'chowder',
#  'chris',
#  'christmas',
#  'cider',
#  'cinnamon',
#  'city',
#  'clam',
#  'class',
#  'classes',
#  'classic',
#  'clean',
#  'cleaning',
#  'clear',
#  'close',
#  'closed',
#  'closes',
#  'closing',
#  'clothes',
#  'club',
#  'cocktail',
#  'cocktails',
#  'coconut',
#  'code',
#  'coffee',
#  'coke',
#  'cold',
#  'color',
#  'com',
#  'combination',
#  'combo',
#  'come',
#  'comes',
#  'comfort',
#  'comfortable',
#  'comfy',
#  'coming',
#  'community',
#  'company',
#  'compared',
#  'complaints',
#  'complete',
#  'completely',
#  'complimentary',
#  'con',
#  'consider',
#  'consistent',
#  'consistently',
#  'construction',
#  'convenient',
#  'cook',
#  'cooked',
#  'cookie',
#  'cookies',
#  'cooking',
#  'cool',
#  'corn',
#  'corned',
#  'corner',
#  'correct',
#  'cost',
#  'costco',
#  'costs',
#  'could',
#  'counter',
#  'country',
#  'county',
#  'couple',
#  'coupon',
#  'coupons',
#  'course',
#  'court',
#  'courteous',
#  'cover',
#  'covered',
#  'covid',
#  'cozy',
#  'crab',
#  'craft',
#  'crap',
#  'craving',
#  'crawfish',
#  'crazy',
#  'cream',
#  'creamy',
#  'creative',
#  'credit',
#  'crepe',
#  'crepes',
#  'crew',
#  'crisp',
#  'crispy',
#  'croissant',
#  'crowd',
#  'crowded',
#  'crowds',
#  'crust',
#  'cuban',
#  'cuisine',
#  'cup',
#  'cupcake',
#  'cupcakes',
#  'cups',
#  'current',
#  'currently',
#  'curry',
#  'custom',
#  'customer',
#  'customers',
#  'cut',
#  'cute',
#  'cuts',
#  'da',
#  'daily',
#  'dairy',
#  'damn',
#  'dan',
#  'dance',
#  'dark',
#  'date',
#  'daughter',
#  'day',
#  'days',
#  'de',
#  'dead',
#  'deal',
#  'deals',
#  'debit',
#  'decent',
#  'decide',
#  'decided',
#  'deck',
#  'decor',
#  'deep',
#  'def',
#  'definitely',
#  'deli',
#  'delicious',
#  'delightful',
#  'delish',
#  'deliver',
#  'delivered',
#  'delivery',
#  'deme',
#  'department',
#  'desert',
#  'design',
#  'desk',
#  'despite',
#  'dessert',
#  'desserts',
#  'die',
#  'diet',
#  'different',
#  'difficult',
#  'dim',
#  'dine',
#  'diner',
#  'dining',
#  'dinner',
#  'dip',
#  'dirty',
#  'disappoint',
#  'disappointed',
#  'disappointing',
#  'discount',
#  'discounts',
#  'disgusting',
#  'dish',
#  'dishes',
#  'dive',
#  'divine',
#  'dj',
#  'doctor',
#  'dog',
#  'dogs',
#  'dollar',
#  'dollars',
#  'done',
#  'dont',
#  'donut',
#  'donuts',
#  'door',
#  'doors',
#  'double',
#  'download',
#  'downstairs',
#  'downtown',
#  'dozen',
#  'dr',
#  'draft',
#  'drafts',
#  'dress',
#  'dressing',
#  'drink',
#  'drinking',
#  'drinks',
#  'drip',
#  'drive',
#  'driving',
#  'drop',
#  'drunk',
#  'dry',
#  'duck',
#  'due',
#  'duke',
#  'dumplings',
#  'earlier',
#  'early',
#  'earn',
#  'earth',
#  'easier',
#  'easily',
#  'east',
#  'easy',
#  'eat',
#  'eaten',
#  'eating',
#  'eats',
#  'efficient',
#  'egg',
#  'eggplant',
#  'eggs',
#  'either',
#  'el',
#  'else',
#  'elsewhere',
#  'em',
#  'email',
#  'employee',
#  'employees',
#  'empty',
#  'enchiladas',
#  'end',
#  'ended',
#  'ends',
#  'energy',
#  'enjoy',
#  'enjoyed',
#  'enjoying',
#  'enough',
#  'enter',
#  'entire',
#  'entrance',
#  'entree',
#  'entrees',
#  'environment',
#  'equipment',
#  'especially',
#  'espresso',
#  'establishment',
#  'etc',
#  'even',
#  'evening',
#  'evenings',
#  'event',
#  'events',
#  'ever',
#  'every',
#  'everyday',
#  'everyone',
#  'everything',
#  'everytime',
#  'everywhere',
#  'exactly',
#  'excellent',
#  'except',
#  'exceptional',
#  'excited',
#  'expect',
#  'expected',
#  'expensive',
#  'experience',
#  'express',
#  'extensive',
#  'extra',
#  'extremely',
#  'eye',
#  'eyes',
#  'fabulous',
#  'face',
#  'facebook',
#  'facility',
#  'fact',
#  'fair',
#  'fairly',
#  'fajitas',
#  'falafel',
#  'fall',
#  'family',
#  'famous',
#  'fan',
#  'fancy',
#  'fans',
#  'fantastic',
#  'far',
#  'fare',
#  'fast',
#  'faster',
#  'fat',
#  'fav',
#  'fave',
#  'favor',
#  'favorite',
#  'favorites',
#  'fee',
#  'feel',
#  'feeling',
#  'feels',
#  'feet',
#  'felt',
#  'fi',
#  'filet',
#  'fill',
#  'filled',
#  'filling',
#  'fills',
#  'finally',
#  'find',
#  'fine',
#  'finish',
#  'fire',
#  'first',
#  'fish',
#  'fit',
#  'five',
#  'fix',
#  'fixed',
#  'flat',
#  'flatbread',
#  'flavor',
#  'flavored',
#  'flavorful',
#  'flavors',
#  'flight',
#  'flights',
#  'floor',
#  'florida',
#  'folks',
#  'follow',
#  'food',
#  'foods',
#  'foot',
#  'football',
#  'forever',
#  'forget',
#  'forgot',
#  'forward',
#  'found',
#  'fountain',
#  'four',
#  'freaking',
#  'free',
#  'french',
#  'frequent',
#  'fresh',
#  'freshest',
#  'freshly',
#  'fri',
#  'friday',
#  'fridays',
#  'fried',
#  'friend',
#  'friendly',
#  'friends',
#  'fries',
#  'front',
#  'frozen',
#  'fruit',
#  'fry',
#  'ftw',
#  'full',
#  'fun',
#  'funny',
#  'furniture',
#  'future',
#  'fyi',
#  'game',
#  'games',
#  'garage',
#  'garden',
#  'garlic',
#  'gas',
#  'gave',
#  'gel',
#  'gelato',
#  'gem',
#  'general',
#  'generous',
#  'german',
#  'get',
#  'gets',
#  'getting',
#  'giant',
#  'gift',
#  'ginger',
#  'girl',
#  'girls',
#  'give',
#  'given',
#  'gives',
#  'giving',
#  'glad',
#  'glass',
#  'glasses',
#  'gluten',
#  'go',
#  'goat',
#  'god',
#  'goes',
#  'going',
#  'gold',
#  'gone',
#  'gonna',
#  'good',
#  'goodness',
#  'goods',
#  'gorgeous',
#  'got',
#  'gotta',
#  'gotten',
#  'grab',
#  'grand',
#  'gravy',
#  'greasy',
#  'great',
#  'greek',
#  'green',
#  'greens',
#  'grill',
#  'grilled',
#  'grits',
#  'grocery',
#  'gross',
#  'ground',
#  'group',
#  'grouper',
#  'groupon',
#  'groups',
#  'guacamole',
#  'guess',
#  'guest',
#  'guests',
#  'gumbo',
#  'guy',
#  'guys',
#  'gym',
#  'gyro',
#  'hair',
#  'haircut',
#  'half',
#  'ham',
#  'hand',
#  'handle',
#  'hands',
#  'hang',
#  'hanging',
#  'happened',
#  'happy',
#  'hard',
#  'hash',
#  'hate',
#  'hazelnut',
#  'head',
#  'health',
#  'healthy',
#  'hear',
#  'heard',
#  'heart',
#  'heat',
#  'heaven',
#  'heavenly',
#  'heavy',
#  'hell',
#  'hello',
#  'help',
#  'helpful',
#  'helps',
#  'hey',
#  'hh',
#  'hi',
#  'hibachi',
#  'hidden',
#  'high',
#  'highly',
#  'hill',
#  'hit',
#  'hoagie',
#  'hoagies',
#  'hold',
#  'hole',
#  'holiday',
#  'holidays',
#  'holy',
#  'home',
#  'homemade',
#  'honest',
#  'honestly',
#  'honey',
#  'honor',
#  'hope',
#  'horrible',
#  'hospitality',
#  'host',
#  'hostess',
#  'hot',
#  'hotel',
#  'hour',
#  'hours',
#  'house',
#  'however',
#  'hubby',
#  'huge',
#  'hummus',
#  'hungry',
#  'hurry',
#  'husband',
#  'ice',
#  'iced',
#  'id',
#  'idea',
#  'im',
#  'important',
#  'impressed',
#  'improved',
#  'include',
#  'included',
#  'includes',
#  'including',
#  'incredible',
#  'incredibly',
#  'indian',
#  'indoor',
#  'indy',
#  'inexpensive',
#  'ingredients',
#  'ins',
#  'inside',
#  'instead',
#  'interesting',
#  'interior',
#  'internet',
#  'ipa',
#  'irish',
#  'island',
#  'issue',
#  'issues',
#  'italian',
#  'item',
#  'items',
#  'jack',
#  'jalapeño',
#  'jam',
#  'japanese',
#  'jazz',
#  'jerk',
#  'jersey',
#  'job',
#  'joe',
#  'john',
#  'join',
#  'joint',
#  'joke',
#  'jose',
#  'juice',
#  'juices',
#  'juicy',
#  'july',
#  'june',
#  'kale',
#  'karaoke',
#  'keep',
#  'keeps',
#  'kept',
#  'ketchup',
#  'key',
#  'kick',
#  'kid',
#  'kids',
#  'killer',
#  'kind',
#  'kinda',
#  'king',
#  'kitchen',
#  'knew',
#  'know',
#  'knowledgeable',
#  'known',
#  'knows',
#  'korean',
#  'la',
#  'lack',
#  'ladies',
#  'lady',
#  'laid',
#  'lamb',
#  'lane',
#  'large',
#  'larger',
#  'last',
#  'late',
#  'later',
#  'latte',
#  'lb',
#  'learn',
#  'least',
#  'leave',
#  'leaves',
#  'leaving',
#  'left',
#  'legit',
#  'legs',
#  'lemon',
#  'lemonade',
#  'less',
#  'let',
#  'lettuce',
#  'level',
#  'life',
#  'light',
#  'lights',
#  'like',
#  'liked',
#  'lime',
#  'limited',
#  'line',
#  'lines',
#  'liquor',
#  'list',
#  'listed',
#  'listen',
#  'literally',
#  'little',
#  'live',
#  'lived',
#  'living',
#  'loaded',
#  'lobby',
#  'lobster',
#  'local',
#  'locally',
#  ...]

# %%
# need these helper methods pretty soon

def get_top_values(lst, n, labels):
    '''
    INPUT: LIST, INTEGER, LIST
    OUTPUT: LIST

    Given a list of values, find the indices with the highest n values.
    Return the labels for each of these indices.

    e.g.
    lst = [7, 3, 2, 4, 1]
    n = 2
    labels = ["cat", "dog", "mouse", "pig", "rabbit"]
    output: ["cat", "pig"]
    '''
    return [labels[i] for i in np.argsort(lst)[::-1][:n]]  # np.argsort by default sorts values in ascending order

def get_bottom_values(lst, n, labels):
    '''
    INPUT: LIST, INTEGER, LIST
    OUTPUT: LIST

    Given a list of values, find the indices with the lowest n values.
    Return the labels for each of these indices.

    e.g.
    lst = [7, 3, 2, 4, 1]
    n = 2
    labels = ["cat", "dog", "mouse", "pig", "rabbit"]
    output: ["mouse", "rabbit"]
    '''
    return [labels[i] for i in np.argsort(lst)[:n]]

# %%
# use cosine similarity
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Draw an arbitrary review from test (unseen in training) documents
random_number = 20
search_query = [documents_test[random_number]]
print(search_query)
# Out:
# ['Knowledge is power!']

# %%
# Transform the drawn resview(s) to vector(s)
vector_search_query = tfidf_vectorizer.transform(search_query).toarray()

# Calculate the similarity score(s) between vector(s) and training vectors
similarity_scores = cosine_similarity(vector_search_query, vectors_train)

# %%
vectors_train.shape, vectors_test.shape , similarity_scores.shape
# Out:
# ((121894, 2000), (284421, 2000), (1, 121894))

# %%
# Let's find top 10 similar reviews
import numpy as np 
n = 10
top_similar_reviews = get_top_values(similarity_scores[0], n, documents_train)

# %%
top_similar_reviews
# Out:
# ['Blackout... No power',
#  'Alles inordnung...power !',
#  'Power lunch!',
#  'Power (Happy) Hour with @Sierra @Carla @Zarna',
#  'Power breakfast sandwich.',
#  "It's raining again. If the power goes out - we good!",
#  'Beautiful place even with the power plant.',
#  "Watch out for the for me the bouncer, he's on a major power trip.",
#  'Breakfast power sandwich....a must try',
#  'This location has a decent selection of power tools.',
#  'There are not enough power outlets!',
#  'You get a free power boost with every purchase!',
#  'Only place with power. Nice people good food jiffy service. Happy',
#  'Free WiFi & power plugs.  Bathrooms',
#  'Under the bar ledge is a power outlet and purse hook at every other stool. Drink up, charge up!',
#  'Power dining 100%.  Suit up, prep your contract, bring your client.  Make a killing.',
#  'Check the phone booths in the terminals for free power outlets.',
#  'Flower Power on tap, come join us!',
#  'I can literally kill the spinach power salad in record time, it is that good!!',
#  'Outdoor seating with power outlets = awesome',
#  'The Strawberry banana power boost smoothie is delicious',
#  'Opportunity to test your will power each time you pass the bucket of tootsie rolls at the check-in counter',
#  "Phone lines , internet, power down.  Doesn't help.",
#  "Phone lines , internet, power down.  Doesn't help.",
#  "Phone lines , internet, power down.  Doesn't help.",
#  'The Power of Children exhibit definitely takes the cake as my favorite.',
#  'The tables on the wall to the right of the bar have power outlets.',
#  "Don't forget their new power hour. \nCome to the bar for Power Hour! $1.00 Wells, Select drafts, House wines.\nSunday through Friday from 4pm to 5pm and Sunday through Thursday 10pm to Close.",
#  'power outlets can be found behind the bench in the inside room',
#  'Power yoga: less chanting, more panting. Troy said it perfectly today.',
#  "June 2016: The power outlets at Gate C28 do not work. That's a bummer.",
#  "Liberty Food & Wine Exchange's Hospitality Industry Partnerships (H.I.P.) will not be holding their meal distribution in Carson City today due to a power outage.",
#  'The breakfast power sandwich is perfectly-sized, delish, and only 300 cals with egg whites.',
#  'Ask about the power shots! (Shooters) & the Dunedin Brewery Apricot Wheat draft if you wanna tease your tastebuds!',
#  'Ask about the power shots! (Shooters) & the Dunedin Brewery Apricot Wheat draft if you wanna tease your tastebuds!',
#  'Outlets galore- a plus for event planning for your power needs',
#  'This is the only place in town that recommend getting keys made. The staff is so friendly and super fast. Girl Power!',
#  'Friendly staff.  I ended up with a new in box crate power block.   Sorry mock L !',
#  'I would not recommend this place as a bouncer I have dealt with at this place is far to aggressive and really harassed people throughout the night I was there. This guy had a power trip',
#  'Power lunch might be the best deal on the menu for $8 salad + popcorn + banana + water.',
#  'The Deli hosts its anniversary show tonight! With music from The Extraordinaires, An American Chinese, and Power Animal!',
#  'Lots of chairs while you wait but VERY LIMITED power outlets, so fully charge electronics beforehand, if possible.',
#  'Power Hour Wednesday- Friday 4:20 ish to 5:20 ish - 1/2 off all pints.  Such a deal!!!',
#  'Tried to come an see a movie this morning an the movie theaters power is out.',
#  'Tried to come an see a movie this morning an the movie theaters power is out.',
#  'If you need to charge your phone, get the 2nd booth table from side entrance has a power outlet',
#  'If you need to charge your phone, get the 2nd booth table from side entrance has a power outlet',
#  "They don't sell quarter sandwiches. Just gotta power through and try to eat half of one. Skip the chips.",
#  '20 min amrap:   5 (100#) power cleans, 10 toes to bar, 15 (14#) wall balls.  =4 rounds RX',
#  'Hot yoga power with Nice is tough but worth it! Packed house, so arrive early and bring your towels.',
#  "Very early Christmas sales. Great if you like these types of items, I don't but my friend went bananas. Beware the power sale.",
#  'To the owners -- you need to digitize!  Add power outlets at each of your tables and along the bar.  Offer fast, robust WIFI.  Stuff like that.',
#  "The parking is a little difficult unfortunately because their is a power Pole in the way, and if you're unsure of the ramen choice best bet is noble ramen!!",
#  'Power breakfast base - highly recommend! The candied bacon is a tasty treat and eggs were poached perfectly. \n\nBut, make sure you have a full charge on electronics, no outlets!',
#  'Pretty bad even by airport standards. Expensive for bad food. Basically the only sit down food in A east. At least they have power outlets.',
#  'We had them amend their policy to include yelp, not just Facebook for the free check in cookie :) (or pickle, or lollipop. we opted for cookie) the power of yelp grows.',
#  'Try eBus instead of Red Arrow. Same company, no snacks, no reserved seating. Still WiFi and power outlets (and often your own seat anyways), and half the price.',
#  'Kudos to management here! In my early December review I criticized their Corkage Fee. Management reached out to me through Yelp and informed me that the fee is now history. Behold the power of Yelp!',
#  'Maybe the worst major airport in the US for the frequent business traveler. Incredibly rude & lazy agents & employees. The gates are straight out of the 80s; horrible lighting, concrete walls, limited restaurants, and no power outlets at the gates.',
#  'Make sure you get desert. It was not on the menu, but they have a good selection of them, and they are well made and taste great. The chocolate torta was delicious with hazenut, chocholate and vanilla ice cream top with chocolate power, and rich chocolate syrup. \nTheir seafood pasta is a must have.',
#  'A power shot from the juice bar - wheatgrass juice, lemon juice and fresh ginger - is a great pick-me-up. I like mine with double ginger.',
#  'A power shot from the juice bar - wheatgrass juice, lemon juice and fresh ginger - is a great pick-me-up. I like mine with double ginger.',
#  "Don't even visit the makeup/beauty aisle unless you like the cashier in the aisle to follow and harass you, and look inside your cart and treat you like a thief. Buy makeup somewhere else, rather than dealing with this nonsense and rude employees on a power trip. Also, you have buy makeup in the aisle now, and can't leave the aisle with any makeup items. At night time they completely close down the aisle.",
#  "Never would have thought I'd find sushi & sake in the Philly airport. Decent and a real treat when compared to 'airport fare' across the country. The sushi bar has power cords all along the bar which is great for the traveling business peeps. The service was attentive and quick.",
#  "Sign up immediately to become a fold star memebr to earn free nights.   Also, the free three drinks, you can ask for a double, or all three if the time is ticking close to 7....Make sure you get you r drink ticket when you check in power person.....Also your bar maid, she doesn't have a tip jar out front....I don't think I've seen any tip jars in Any of the drury hotels, but it does help.  :-)",
#  'The first meal of freedom after 48days \nWas the best...',
#  'Volunteer Appreciation Week',
#  'Not much in the wig selection for blonds',
#  'Tots and shots!',
#  'They always have my mobile order ready on time. Nice employees and good service.',
#  'Cash ONLY but once you get past the unfriendly guy at the counter then you can enjoy a tasty slice from the best pizza place on South Street!',
#  'I had Cassie for my game master and she was the BEST, a1 attitude!',
#  "First day, let's see what they got!",
#  'Be willing to try some of the different types of blow outs. There is a big difference between a curling iron and a wand. Today I went wand for the relaxed curl look.',
#  'Great lounge area great drinks,  good staff,  comfortable seating and entertainment most evenings',
#  "It's fast food....and that's all I have to say about that",
#  'Food was amazing, the spicy Korean chicken sandwich and fried calamari were awesome!',
#  'Been going here for years, always quality food.',
#  'We got the Korean Joekbal, it is a foot of pig that was served with a cup of some spicy sauce. Tasted Scrumptious!',
#  "I got a mushroom panini with fresh mushrooms grown by one of the cooks. Omg I'm in Heaven. What a treat",
#  "Don't drink too quickly, the large straws cause you to suck in a lot of air and can make you bloated. Also, if you like the flavor of the drink with just a bit of texture, get half the amount of pearls so you're not sucking up a ball with every sip.",
#  'Jazz Brunch.  Service great if a bit rushed.  The food is phenomenal.',
#  'Most of the Veggie sides contain meat. Not vegetarian friendly.',
#  'Best rye toast ever. Now I always want rye with my dippy eggs.',
#  'Great dive bar. Good music and friendly staff. Spotless restrooms',
#  'Go cards!',
#  "I am unable to check in at this Carrabba's. This is the fifth time I have been here and tried to check in.",
#  'At one of our favorite places.',
#  'Open late, kids gotta have it!!',
#  'They serve O T Hodge Chili',
#  'Excellent Mexican food and great value - large portions and fast!',
#  'New favorite spot',
#  'Gnocchi is always a good idea... And make a reservation... Everyone loves this place',
#  'Quiet on Sunday evening',
#  'Still fantastic!!',
#  'Dont go here. End of story.',
#  'Good crab cakes and SoCo with Ginger ale.... LOL!!!',
#  'Yo. Your food is bomb but the service sucks ass.',
#  'Great little place on Magazine. Cool atmosphere, quick service, wonderful food!',
#  'Prime  location, prime food and great experience']

# %%
print('Our search query:')
print(search_query[0])
# Out:
# Our search query:
# Knowledge is power!

# %%
print('query')
print(search_query)  

print('\n\nMost %s similar reviews:' % n)
for i, review in enumerate(top_similar_reviews):
    print('#%s:' % i)
    print(review)
# Out:
# query
# ['Knowledge is power!']
#
#
# Most 10 similar reviews:
# #0:
# Blackout... No power
# #1:
# Alles inordnung...power !
# #2:
# Power lunch!
# #3:
# Power (Happy) Hour with @Sierra @Carla @Zarna
# #4:
# Power breakfast sandwich.
# #5:
# It's raining again. If the power goes out - we good!
# #6:
# Beautiful place even with the power plant.
# #7:
# Watch out for the for me the bouncer, he's on a major power trip.
# #8:
# Breakfast power sandwich....a must try
# #9:
# This location has a decent selection of power tools.

# %%
 # Classifying positive/negative review
# Naive-Bayes Classifier
# Build a Naive-Bayes Classifier
from sklearn.naive_bayes import MultinomialNB

model_nb = MultinomialNB()

model_nb.fit(vectors_train, target_train)
MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)
# Get score for training set
model_nb.score(vectors_train, target_train)
# Out:
# 0.6514594647808752

# %%
# Get score for test set
model_nb.score(vectors_test, target_test)
# Out:
# 0.6405609993636194

# %%
# Logistic Regression Classifier
target_train.shape
(14742,)
# Build a Logistic Regression Classifier

from sklearn.linear_model import LogisticRegression

model_lrc = LogisticRegression()
model_lrc.fit(vectors_train, target_train)
LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
          intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
          penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
          verbose=0, warm_start=False)
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression(multi_class='ovr', n_jobs=1, solver='liblinear')

# %%
# Get score for training set
model_lrc.score(vectors_train, target_train)
# Out:
# 0.6678343478760235

# %%
# Get score for test set
model_lrc.score(vectors_test, target_test)
# Out:
# 0.6520791362100549

# %%
# Q: What are the key features(words) that make the positive prediction?
# Let's find it out by ranking
n = 50
get_top_values(model_lrc.coef_[0], n, wordspitts)
# Out:
# ['charro',
#  'deme',
#  'seca',
#  'best',
#  'amazing',
#  'bri',
#  'maggie',
#  'heaven',
#  'favorite',
#  'professional',
#  'highly',
#  'mocha',
#  'ftw',
#  'jose',
#  'regret',
#  'delicious',
#  'loved',
#  'incredible',
#  'awesome',
#  'love',
#  'honest',
#  'reasonably',
#  'disappoint',
#  'cuts',
#  'die',
#  'wonderful',
#  'advance',
#  'everything',
#  'great',
#  'excellent',
#  'fabulous',
#  'fantastic',
#  'perfection',
#  'unbelievable',
#  'phenomenal',
#  'tucson',
#  'fav',
#  'beautiful',
#  'boise',
#  'killer',
#  'unique',
#  'notch',
#  'knowledgeable',
#  'perfect',
#  'products',
#  'row',
#  'brazilian',
#  'drip',
#  'exceptional',
#  '100']

# %%
# Q: What are the key features(words) that make the negative prediction?
# Let's find it out by ranking
n = 30
get_bottom_values(model_lrc.coef_[0], n, wordspitts)
# Out:
# ['worst',
#  'horrible',
#  'rude',
#  'terrible',
#  'mediocre',
#  'overpriced',
#  'bland',
#  'poor',
#  'disgusting',
#  'sucks',
#  'worse',
#  'slow',
#  'somewhere',
#  'average',
#  'waste',
#  'awful',
#  'ok',
#  'gross',
#  'okay',
#  'bother',
#  'decent',
#  'poisoning',
#  'unprofessional',
#  'meh',
#  'managers',
#  'however',
#  'ugh',
#  'told',
#  'avoid',
#  'expensive']

# %%
# Build a Random Forest Classifier

from sklearn.ensemble import RandomForestClassifier
model_rfc = RandomForestClassifier(max_depth = 25, n_estimators = 200, random_state = 42)

model_rfc.fit(vectors_train, target_train)
# Out:
# RandomForestClassifier(max_depth=25, n_estimators=200, random_state=42)

# %%
# Get score for training set
model_rfc.score(vectors_train, target_train)
# Out:
# 0.6552168277355735

# %%
# Get score for test set
model_rfc.score(vectors_test, target_test)
# Out:
# 0.6364016721690733

# %%
model_rfc

# %% [markdown]
# # Q: What do you see from the training score and the test score?
# The trainng score and the test score are comparable, seems no negative impact of overfitting.
#
# And the scores fo Random forest are slightly better than Logistic regression. If the data size is larger, the advantage fo Random forest may be more obvious.

# %%
# Q: Can you tell what features (words) are important by inspecting the RFC model?
n = 50
get_top_values(model_rfc.feature_importances_, n, wordspitts)
# Out:
# ['best',
#  'amazing',
#  'great',
#  'love',
#  'awesome',
#  'delicious',
#  'horrible',
#  'rude',
#  'worst',
#  'food',
#  'excellent',
#  'terrible',
#  'favorite',
#  'slow',
#  'place',
#  'ok',
#  'friendly',
#  'highly',
#  'service',
#  'bad',
#  'money',
#  'poor',
#  'always',
#  'overpriced',
#  'staff',
#  'avoid',
#  'everything',
#  'ever',
#  'good',
#  'town',
#  'mediocre',
#  'wonderful',
#  'fantastic',
#  'awful',
#  'try',
#  'loved',
#  'sucks',
#  'somewhere',
#  'recommend',
#  'waste',
#  'decent',
#  'average',
#  'fresh',
#  'go',
#  'minutes',
#  'atmosphere',
#  'must',
#  'hour',
#  'bland',
#  'expensive']
